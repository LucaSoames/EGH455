# %% [markdown]
# <a href="https://colab.research.google.com/github/LucaSoames/EGH455/blob/main/models/YOLOv5_training_NEW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %% [markdown]
# # Install YOLOv5

# %%
# Set path to clone YOLOv5 repo
# %cd ./models
# %ls

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5 YOLOv5
# Out:
# Cloning into 'YOLOv5'...

# %%
# install dependencies as necessary
# !pip install -r YOLOv5/requirements.txt
# !pip uninstall wandb -qy  # deprecated dependency
import torch

from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.8.0+cpu CPU

# %%
# Change to YOLOv5 directory
# %cd YOLOv5/
# %ls

# %%
# Install Roboflow package
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Yg0BQvifINgpEz0Z2JI3")
project = rf.workspace("egh455-tblnn").project("egh455-jtll2-bvooc")
version = project.version(3)
clear_output()                
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (1.2.7)
# Requirement already satisfied: certifi in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (3.10.5)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (2.2.6)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from matplotlib->roboflow) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ncart\miniconda3\envs\egh455\lib\site-packages (from requests->roboflow) (3.4.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in EGH455-3 to yolov5pytorch:: 100%|██████████| 436406/436406 [00:38<00:00, 11267.22it/s]
# Extracting Dataset Version Zip to EGH455-3 in yolov5pytorch:: 100%|██████████| 11284/11284 [00:21<00:00, 523.88it/s]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **cache:** cache images for faster training

# %%
# Make sure we are in the YOLOv5 directory
# %ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 82A6-EE0C
#
#  Directory of c:\Users\ncart\OneDrive\QUT\EGH455 Advanced Systems Design\EGH455\models\YOLOv5
#
# 30/08/2025  09:35 AM    <DIR>          .
# 30/08/2025  09:30 AM    <DIR>          ..
# 30/08/2025  09:30 AM             3,923 .dockerignore
# 30/08/2025  09:30 AM                77 .gitattributes
# 30/08/2025  09:31 AM    <DIR>          .github
# 30/08/2025  09:30 AM             4,268 .gitignore
# 30/08/2025  09:30 AM            14,440 benchmarks.py
# 30/08/2025  09:30 AM               407 CITATION.cff
# 30/08/2025  09:31 AM    <DIR>          classify
# 30/08/2025  09:30 AM             5,506 CONTRIBUTING.md
# 30/08/2025  09:31 AM    <DIR>          data
# 30/08/2025  09:30 AM            24,199 detect.py
# 30/08/2025  09:36 AM    <DIR>          EGH455-3
# 30/08/2025  09:30 AM            70,181 export.py
# 30/08/2025  09:30 AM            24,543 hubconf.py
# 30/08/2025  09:30 AM            35,184 LICENSE
# 30/08/2025  09:31 AM    <DIR>          models
# 30/08/2025  09:30 AM             5,533 pyproject.toml
# 30/08/2025  09:30 AM            50,540 README.md
# 30/08/2025  09:30 AM            49,509 README.zh-CN.md
# 30/08/2025  09:30 AM             1,708 requirements.txt
# 30/08/2025  09:31 AM    <DIR>          segment
# 30/08/2025  10:23 AM            48,206 train.py
# 30/08/2025  10:14 AM            40,841 tutorial.ipynb
# 30/08/2025  09:31 AM    <DIR>          utils
# 30/08/2025  09:30 AM            31,053 val.py
#               17 File(s)        410,118 bytes
#                9 Dir(s)  360,495,026,176 bytes free

# %%
# Install Comet ML to visualise training (API key from comet.com)
# !pip install comet_ml
clear_output()

print(f"Dataset location: {dataset.location}")
yaml_path = dataset.location + "\data.yaml"
print(f"YAML path: {yaml_path}")


import os
os.environ['COMET_API_KEY'] = 'OcJ0c4XCSTYcwMCpISu2YBObc'
# !export COMET_API_KEY=OcJ0c4XCSTYcwMCpISu2YBObc 
COMET_API_KEY = os.getenv('COMET_API_KEY')
print(COMET_API_KEY)  # Check if the COMET_API_KEY is set correctly
# Out:
# Dataset location: c:\Users\ncart\OneDrive\QUT\EGH455 Advanced Systems Design\EGH455\models\YOLOv5\EGH455-3
# YAML path: c:\Users\ncart\OneDrive\QUT\EGH455 Advanced Systems Design\EGH455\models\YOLOv5\EGH455-3\data.yaml
# OcJ0c4XCSTYcwMCpISu2YBObc

# %%
# TRAIN YOLOv5s on custom data for X epochs
# %%time # time its performance

# !python train.py --img 640 --batch 16 --epochs 1 --data "{yaml_path}" --weights yolov5s.pt --name yolov5s_results --cache
# Add --resume to resume training from last epoch
# Out:
#   Cell In[38], line 5
#     --weights "yolov5s.pt" \
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# You can view the training graphs associated with a training job in the `/content/yolov5/runs/train/yolov5s_results/results.png` folder.
#
# Training losses and performance metrics are also saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='/content/yolov5/runs/train/yolov5s_results/val_batch0_labels.jpg', width=900)

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)

# %% [markdown]
# # Run Inference With Trained Weights
#
# Next, we can run inference with a pretrained checkpoint on all images in the `test/images` folder to understand how our model performs on our test set.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/

# %%
# %ls runs/train/yolov5s_results/weights

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.35 --source {dataset.location}/test/images/

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))

# %% [markdown]
# ## Deploy Model on Roboflow
#
# Once you have finished training your YOLOv5 model, you’ll have a set of trained weights ready for use. These weights will be in the `/content/yolov5/runs/train/yolov5s_results/` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv5 weights.
#
# **Before you run this code, make sure you create a new Version in the Roboflow dashboard following the instructions we covered earlier. Fill in your project name, workspace, and version number below.**
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov5", model_path=f"/content/yolov5/runs/train/yolov5s_results/")

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
